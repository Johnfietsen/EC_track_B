# %%
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# ### Setup
# * **path** - variable, which refers to path with robot's csv files
# * **start** - index of first robot's csv file
# * **end** - index of last robot's csv file (open interval, it should be (last + 1) )
# * **experiments** - number of experiments

# %%
path = '../data/re3simro21..30/'
start = 21 
end = 31
experiments = 3

# %% [markdown]
# ### Load data from csv file

# %%
data = []
names = []
for i in range(start, end):
    for ex in range(1,  experiments + 1):
        filename = 'robot_{}-{}.csv'.format(i,ex) # creating filename
        
        temp = np.genfromtxt(path + filename, delimiter=',') #loading data from file
        temp = temp[~np.isnan(temp)] # deleting last nan value, because the file contains comma after last value
        # so it reads it as nan value, but there is actually no value
        data.append(temp)
        names.append(filename.split(".")[0].split("_")[1]) # we want to omit .csv ending and robot prefix
        
data = pd.DataFrame(dict(zip(names, data)), columns=names)

# %% [markdown]
# ### Plotting the robots from table

# %%
plt.rcParams['figure.figsize'] = [7, 5]
for robot in data.columns:
    
    x = np.arange(0, data.shape[0])
    
    plt.subplot(2, 1, 1)
    plt.title("Plotting: {}".format(robot))
    plt.plot(x, data[robot], 'o')
    
    
    #Get 10 group means and then plot
    g10 = data[robot].values.reshape((-1,10))
    g10 = g10.mean(axis=1)
    
    plt.subplot(2, 1, 2)
    plt.plot(np.arange(0, g10.size), g10)
    
    plt.show()
    
    
    
    
    print("""
    Mean:                                     {}
    std:                                      {}
    Maximmum value:                           {}
    MAximmum value in generation:             {}
    Average Gradient:                         {}
    Diff (last - first):                      {}
    """.format(data[robot].mean(), 
               data[robot].std(), 
               data[robot].max(),
               data[robot].idxmax(),
               np.gradient(data[robot].values).mean(),
               (data[robot].iloc[-1] - data[robot].iloc[0])
              ))
plt.rcParams['figure.figsize'] = [15, 10]
# Out:
#     Mean:                                     0.008421384149999997
#     std:                                      0.0015596554240094903
#     Maximmum value:                           0.00898408
#     MAximmum value in generation:             744
#     Average Gradient:                         7.656835000000002e-06
#     Diff (last - first):                      0.0075175500000000004
#     Mean:                                     0.004225979922699997
#     std:                                      0.0033134156673308287
#     Maximmum value:                           0.00991459
#     MAximmum value in generation:             349
#     Average Gradient:                         1.54601e-06
#     Diff (last - first):                      0.00029115
#     Mean:                                     0.0029907214150999973
#     std:                                      0.0024162213460025618
#     Maximmum value:                           0.0100299
#     MAximmum value in generation:             300
#     Average Gradient:                         -1.8084780000000002e-06
#     Diff (last - first):                      -0.0014122619999999998
#     Mean:                                     0.0081160279312
#     std:                                      0.004843812795064427
#     Maximmum value:                           0.0123113
#     MAximmum value in generation:             665
#     Average Gradient:                         1.2783605249999993e-05
#     Diff (last - first):                      0.0121930035
#     Mean:                                     0.010495748593500002
#     std:                                      0.00320410347919295
#     Maximmum value:                           0.0128107
#     MAximmum value in generation:             655
#     Average Gradient:                         9.703723000000001e-06
#     Diff (last - first):                      0.01026614
#     Mean:                                     0.008730527256999993
#     std:                                      0.0014743584046141656
#     Maximmum value:                           0.00945222
#     MAximmum value in generation:             433
#     Average Gradient:                         8.576091000000001e-06
#     Diff (last - first):                      0.008505327
#     Mean:                                     0.012040867904299994
#     std:                                      0.008491583743020097
#     Maximmum value:                           0.025114
#     MAximmum value in generation:             825
#     Average Gradient:                         -7.159814999999972e-07
#     Diff (last - first):                      0.0012149300000000001
#     Mean:                                     0.019977087623599992
#     std:                                      0.00958828816086993
#     Maximmum value:                           0.0304001
#     MAximmum value in generation:             659
#     Average Gradient:                         2.1451100000000333e-06
#     Diff (last - first):                      0.0042748099999999995
#     Mean:                                     0.01517295931799999
#     std:                                      0.00924264944985359
#     Maximmum value:                           0.0285343
#     MAximmum value in generation:             993
#     Average Gradient:                         2.989353100000002e-05
#     Diff (last - first):                      0.027601684
#     Mean:                                     0.02338310494410001
#     std:                                      0.009206085090983371
#     Maximmum value:                           0.0307235
#     MAximmum value in generation:             959
#     Average Gradient:                         2.9819793000000006e-05
#     Diff (last - first):                      0.029071712
#     Mean:                                     0.018802524904000025
#     std:                                      0.00933502772474298
#     Maximmum value:                           0.0308951
#     MAximmum value in generation:             348
#     Average Gradient:                         1.3464534999999988e-05
#     Diff (last - first):                      0.01671607
#     Mean:                                     0.02653523438429998
#     std:                                      0.008202950612594642
#     Maximmum value:                           0.0340606
#     MAximmum value in generation:             766
#     Average Gradient:                         2.8282015e-05
#     Diff (last - first):                      0.027898959999999997
#     Mean:                                     0.005840229375999995
#     std:                                      0.006526354038883904
#     Maximmum value:                           0.0193068
#     MAximmum value in generation:             302
#     Average Gradient:                         -3.3943889999999387e-07
#     Diff (last - first):                      -0.0011948766
#     Mean:                                     0.00794134196870001
#     std:                                      0.007078733123444708
#     Maximmum value:                           0.0215667
#     MAximmum value in generation:             611
#     Average Gradient:                         3.6265000000000427e-07
#     Diff (last - first):                      -0.0007807999999999999
#     Mean:                                     0.02048567147139997
#     std:                                      0.0036107056783380854
#     Maximmum value:                           0.022772
#     MAximmum value in generation:             968
#     Average Gradient:                         2.144207e-05
#     Diff (last - first):                      0.021209617
#     Mean:                                     0.02098570895899999
#     std:                                      0.006362943803137433
#     Maximmum value:                           0.0242728
#     MAximmum value in generation:             460
#     Average Gradient:                         2.13019655e-05
#     Diff (last - first):                      0.02199539
#     Mean:                                     0.023511579606000015
#     std:                                      0.003614853965975687
#     Maximmum value:                           0.0260829
#     MAximmum value in generation:             998
#     Average Gradient:                         2.9726712500000002e-05
#     Diff (last - first):                      0.024718175000000002
#     Mean:                                     0.006220970277899997
#     std:                                      0.004467459387803516
#     Maximmum value:                           0.0219193
#     MAximmum value in generation:             106
#     Average Gradient:                         -1.3337235000000013e-05
#     Diff (last - first):                      -0.01038655
#     Mean:                                     0.008506745534500005
#     std:                                      0.008133071181549064
#     Maximmum value:                           0.0286561
#     MAximmum value in generation:             361
#     Average Gradient:                         -1.0605005000000015e-05
#     Diff (last - first):                      -0.0062206
#     Mean:                                     0.025063756704999995
#     std:                                      0.005612463110743628
#     Maximmum value:                           0.0283034
#     MAximmum value in generation:             635
#     Average Gradient:                         2.3544119999999995e-05
#     Diff (last - first):                      0.02358254
#     Mean:                                     0.012807001211999987
#     std:                                      0.010119771131045207
#     Maximmum value:                           0.0297088
#     MAximmum value in generation:             989
#     Average Gradient:                         2.9247260000000008e-05
#     Diff (last - first):                      0.02797748
#     Mean:                                     0.021178100291999995
#     std:                                      0.005098656918290005
#     Maximmum value:                           0.0250629
#     MAximmum value in generation:             272
#     Average Gradient:                         2.7327059999999992e-05
#     Diff (last - first):                      0.02259258
#     Mean:                                     0.005328357734100004
#     std:                                      0.004446266558813237
#     Maximmum value:                           0.0250376
#     MAximmum value in generation:             190
#     Average Gradient:                         -1.1297900000000115e-06
#     Diff (last - first):                      -0.00080495
#     Mean:                                     0.017537996304
#     std:                                      0.010901386201748223
#     Maximmum value:                           0.031543
#     MAximmum value in generation:             949
#     Average Gradient:                         2.8443355000000006e-05
#     Diff (last - first):                      0.028025880000000003
#     Mean:                                     0.013195051306
#     std:                                      0.006977190080420998
#     Maximmum value:                           0.0201732
#     MAximmum value in generation:             896
#     Average Gradient:                         1.8067219999999997e-05
#     Diff (last - first):                      0.018032299999999998
#     Mean:                                     0.016814380858999993
#     std:                                      0.006770317465857903
#     Maximmum value:                           0.0236662
#     MAximmum value in generation:             897
#     Average Gradient:                         2.153296500000001e-05
#     Diff (last - first):                      0.02056652
#     Mean:                                     0.01701189139400001
#     std:                                      0.004090126934709787
#     Maximmum value:                           0.0200002
#     MAximmum value in generation:             994
#     Average Gradient:                         6.791280499999998e-06
#     Diff (last - first):                      0.011101579999999998
#     Mean:                                     0.0024199018436999948
#     std:                                      0.002415457272953375
#     Maximmum value:                           0.0128127
#     MAximmum value in generation:             106
#     Average Gradient:                         9.693931000000012e-07
#     Diff (last - first):                      0.0017053043999999999
#     Mean:                                     0.003826073131099997
#     std:                                      0.003770780332659376
#     Maximmum value:                           0.0151776
#     MAximmum value in generation:             997
#     Average Gradient:                         1.4101122950000007e-05
#     Diff (last - first):                      0.0143958943
#     Mean:                                     0.0136320149801
#     std:                                      0.0056384747853021056
#     Maximmum value:                           0.0176796
#     MAximmum value in generation:             815
#     Average Gradient:                         1.3186778499999993e-05
#     Diff (last - first):                      0.014394979999999998
